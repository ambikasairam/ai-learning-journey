# %% [markdown]
# <a href="https://colab.research.google.com/github/ambikasairam/ai-learning-journey/blob/main/Week%2001%20%E2%80%93%20Python%20Basics/week_01_python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 01 — Python Basics for AI
#
# This notebook covers basic Python concepts needed for AI and ML.
#
# ## Topics
# - Variables
# - Data types
# - Lists & dictionaries
# - Functions
# - Loops

# %%
# Variables and data types
x = 10
y = 3.5
name = "AI Learner"

print(type(x), type(y), type(name))
z=x+y
print(z, type(z))
f=name + " testing"
print(f, type(f))
# Out:
# <class 'int'> <class 'float'> <class 'str'>
# 13.5 <class 'float'>
# AI Learner testing <class 'str'>

# %%
# Lists and dictionaries
numbers = [1, 2, 3, 4]
person = {"name": "Alicia", "role": "AI Learner"}

print(numbers)
print(person["name"])
# Out:
# [1, 2, 3, 4]
# Alicia

# %%
# Functions
def add(a, b):
    return a + b

add(3, 5)
# Out:
# 8

# %%
# Loops
for i in range(5):
    print("Iteration:", i)
# Out:
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
